# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session

# %%
# !pip install pyngrok flask
# !pip install -U "xformers==0.0.27" --index-url https://download.pytorch.org/whl/cu121
# !pip install "unsloth[colab-new] @ git+https://github.com/unslothai/unsloth.git"
# !pip install  trl peft accelerate bitsandbytes
# Out:
# ...
# Looking in indexes: https://download.pytorch.org/whl/cu121
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 164.1/164.1 MB 10.0 MB/s eta 0:00:0000:0100:01
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 781.0/781.0 MB 2.1 MB/s eta 0:00:0000:0100:01
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 23.7/23.7 MB 46.3 MB/s eta 0:00:0000:0100:01
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 823.6/823.6 kB 43.8 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 14.1/14.1 MB 82.1 MB/s eta 0:00:0000:0100:01
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 731.7/731.7 MB 1.9 MB/s eta 0:00:0000:0100:01
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 410.6/410.6 MB 2.3 MB/s eta 0:00:0000:0100:01
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 121.6/121.6 MB 13.1 MB/s eta 0:00:0000:0100:01
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.5/56.5 MB 29.5 MB/s eta 0:00:0000:0100:01
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 124.2/124.2 MB 13.4 MB/s eta 0:00:0000:0100:01
# ...

# %%
from unsloth import FastLanguageModel
import torch
max_seq_length = 2048 
dtype = None 
load_in_4bit = True
# Out:
# 🦥 Unsloth: Will patch your computer to enable 2x faster free finetuning.

# %%
model, tokenizer = FastLanguageModel.from_pretrained(
    model_name = "AJosh/lora_model1",
    max_seq_length = max_seq_length,
    dtype = dtype,
    load_in_4bit = load_in_4bit,
)
# Out:
# ==((====))==  Unsloth 2024.10.3: Fast Llama patching. Transformers = 4.45.2.
#    \\   /|    GPU: Tesla T4. Max memory: 14.741 GB. Platform = Linux.
# O^O/ \_/ \    Pytorch: 2.3.1+cu121. CUDA = 7.5. CUDA Toolkit = 12.1.
# \        /    Bfloat16 = FALSE. FA [Xformers = 0.0.27. FA2 = False]
#  "-____-"     Free Apache license: http://github.com/unslothai/unsloth
# Unsloth: Fast downloading is enabled - ignore downloading bars which are red colored!
# model.safetensors:   0%|          | 0.00/5.70G [00:00<?, ?B/s]
# generation_config.json:   0%|          | 0.00/230 [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/50.6k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/9.09M [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/345 [00:00<?, ?B/s]
# Unsloth: We fixed a gradient accumulation bug, but it seems like you don't have the latest transformers version!
# Please update transformers via:
# ...

# %%
alpaca_prompt = """Below is an instruction that describes a task, paired with an input that provides further context. Write a response that appropriately completes the request.

### Instruction:
you are a workout plan generator,generate the workout plan according to the given input

### Input:
I am a {} -year-old {} with a height of {}  cm and a weight of {}  kg. My primary goal is {} , and I aim to reach a target weight of {} kg. I am a {}  at the gym. Can you create a 7-day workout plan for me?

### Response:
{}"""

# %%
FastLanguageModel.for_inference(model)
def inference():
    age = int(input("Enter your age: "))
    sex = input("male or female:")
    height = (input("Enter your height in cm: "))
    weight = (input("Enter your current weight in kg: "))
    goal = input("Enter your primary goal (weight loss, endurance, muscle gain, health): ")
    target_weight = (input("Enter your target weight in kg: "))
    experience = input("Enter your experience level (beginner, intermediate, advanced): ")
    output = alpaca_prompt.format(age,sex,height,weight,goal,target_weight,experience," ")
    inputs = tokenizer([output], return_tensors="pt").to("cuda")
    outputs = model.generate(**inputs, max_new_tokens=700, use_cache=True)
    output_text = tokenizer.batch_decode(outputs, skip_special_tokens=True)[0]
    print(output_text)

# %%
# !pip install pyngrok flask

# %%
port_no = 6000
from flask import Flask
from pyngrok import ngrok
from flask import Flask, request, jsonify

# %%
from flask import Flask, request, jsonify
from pyngrok import ngrok
import os

app = Flask(_name_)

PORT = 5000
NGROK_AUTH_TOKEN = "2lGTrPfKaseITcmgdp5ZXnaCrl6_2ABHvnjSSZ9WpLFvV8a2u"
NGROK_DOMAIN = "keen-marten-tops.ngrok-free.app"
ngrok.set_auth_token(NGROK_AUTH_TOKEN)

tunnel_config = {
    "addr": PORT,
    "hostname": NGROK_DOMAIN
}
public_url = ngrok.connect(**tunnel_config)
print(f"Public URL: {public_url}")

@app.route("/")
def home():
    return "Hello World!"

@app.route('/generate', methods=['POST'])
def generate():
    try:
        age = request.get_json()['age']
        sex = request.get_json()['sex']
        height = request.get_json()['height'] 
        weight = request.get_json()['weight']
        goal = request.get_json()['goal']
        target_weight = request.get_json()['target_weight']
        experience = request.get_json()['experience']
        output = alpaca_prompt.format(age,sex,height,weight,goal,target_weight,experience," ")
        inputs = tokenizer([output], return_tensors="pt").to("cuda")
        outputs = model.generate(**inputs, max_new_tokens=700, use_cache=True)
        output_text = tokenizer.batch_decode(outputs, skip_special_tokens=True)[0]
            
        return jsonify({'output': output_text})
    except Exception as e:
        return jsonify({'error': str(e)}), 400

if _name_ == "_main_":
    app.run(host='0.0.0.0', port=PORT)
